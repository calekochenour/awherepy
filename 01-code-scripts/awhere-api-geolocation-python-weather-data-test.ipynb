# %% [markdown]
# # aWhere API Python Geolocation Test & Demonstration

# %% [markdown]
# ## Environment Set Up

# %%
# Imports
import os
import pandas as pd
from pandas.io.json import json_normalize
import geopandas as gpd
from awhere_geolocation import AWhereAPI
import extract_data_geolocation
import clean_data_geolocation

# %%
# Show all Pandas dataframe columns
pd.set_option('display.max_columns', None)

# %%
# Define aWhere API key and secret
api_key = os.environ.get('AWHERE_API_KEY')
api_secret = os.environ.get('AWHERE_API_SECRET')

# %%
# Create aWhere object
aWhere = AWhereAPI(api_key, api_secret)

# %%
# Define coordinates
rmnp_latitude = 40
rmnp_longitude = -105

# %% [markdown]
# ## Weather Forecast

# %%
# Get forecast in raw form
rmnp_forecast = aWhere.get_weather_forecast(
    rmnp_latitude, rmnp_longitude)

# %%
# Display raw data return
rmnp_forecast
# Out:
# {'forecasts': [{'date': '2020-04-11',
#    'location': {'latitude': 40.0, 'longitude': -105.0},
#    'forecast': [{'startTime': '2020-04-11T00:00:00+00:00',
#      'endTime': '2020-04-11T23:59:59+00:00',
#      'conditionsCode': 'C21',
#      'conditionsText': 'Mostly Clear, Light Rain, Light Wind/Calm',
#      'temperatures': {'max': 20.642484664916992,
#       'min': 8.571503639221191,
#       'units': 'C'},
#      'precipitation': {'chance': 0.0,
#       'amount': 0.49999998696148396,
#       'units': 'mm'},
#      'sky': {'cloudCover': 34.0, 'sunshine': 66.0},
#      'solar': {'amount': 7116.0, 'units': 'Wh/m^2'},
#      'relativeHumidity': {'average': 26.454166928927105,
#       'max': 37.0,
#       'min': 12.300000190734863},
#      'wind': {'average': 4.537427436728267,
#       'max': 7.990773155241928,
#       'min': 2.322492156530909,
#       'units': 'm/sec',
#       'bearing': 249.9,
#       'direction': 'WSW'},
#      'dewPoint': {'amount': -5.719110330660034, 'units': 'C'},
#      'soilTemperatures': [{'depth': '0-0.1 m below ground',
#        'average': 13.616607705752054,
#        'max': 18.091724395751953,
#        'min': 10.198389053344727,
#        'units': 'C'},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 10.167496045430502,
#        'max': 10.329999923706055,
#        'min': 10.09000015258789,
#        'units': 'C'},
#       {'depth': '0.4-1 m below ground',
#        'average': 8.070494731267294,
#        'max': 8.172948837280273,
#        'min': 7.972968578338623,
#        'units': 'C'},
#       {'depth': '1-2 m below ground',
#        'average': 7.614109794298808,
#        'max': 7.621757984161377,
#        'min': 7.601758003234863,
#        'units': 'C'}],
#      'soilMoisture': [{'depth': '0-0.1 m below ground',
#        'average': 15.099999705950419,
#        'max': 15.299999237060547,
#        'min': 14.699999809265137},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 18.349405368169148,
#        'max': 18.41190528869629,
#        'min': 18.111906051635742},
#       {'depth': '0.4-1 m below ground',
#        'average': 5.903707504272461,
#        'max': 5.903707504272461,
#        'min': 5.903707504272461},
#       {'depth': '1-2 m below ground',
#        'average': 13.94312858581543,
#        'max': 13.94312858581543,
#        'min': 13.94312858581543}]}],
#    '_links': {'self': {'href': '/v2/weather/locations/40,-105/forecasts/2020-04-11'}}},
#   {'date': '2020-04-12',
#    'location': {'latitude': 40.0, 'longitude': -105.0},
#    'forecast': [{'startTime': '2020-04-12T00:00:00+00:00',
#      'endTime': '2020-04-12T23:59:59+00:00',
#      'conditionsCode': 'F31',
#      'conditionsText': 'Cloudy, Moderate Rain, Light Wind/Calm',
#      'temperatures': {'max': 18.91748046875,
#       'min': -3.0465455055236816,
#       'units': 'C'},
#      'precipitation': {'chance': 100.0,
#       'amount': 3.0624999962747097,
#       'units': 'mm'},
#      'sky': {'cloudCover': 100.0, 'sunshine': 0.0},
#      'solar': {'amount': 5844.0, 'units': 'Wh/m^2'},
#      'relativeHumidity': {'average': 53.0625,
#       'max': 90.9000015258789,
#       'min': 18.299999237060547},
#      'wind': {'average': 5.921989223831704,
#       'max': 10.043753588919282,
#       'min': 2.6060634788570836,
#       'units': 'm/sec',
#       'bearing': 4.0,
#       'direction': 'N'},
#      'dewPoint': {'amount': -5.203474215183234, 'units': 'C'},
#      'soilTemperatures': [{'depth': '0-0.1 m below ground',
#        'average': 11.364468336105347,
#        'max': 17.63753318786621,
#        'min': 7.704882621765137,
#        'units': 'C'},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 10.356249928474426,
#        'max': 10.529999732971191,
#        'min': 10.0600004196167,
#        'units': 'C'},
#       {'depth': '0.4-1 m below ground',
#        'average': 8.301961263020834,
#        'max': 8.392363548278809,
#        'min': 8.186080932617188,
#        'units': 'C'},
#       {'depth': '1-2 m below ground',
#        'average': 7.640648543834686,
#        'max': 7.651757717132568,
#        'min': 7.623313903808594,
#        'units': 'C'}],
#      'soilMoisture': [{'depth': '0-0.1 m below ground',
#        'average': 15.091666420300802,
#        'max': 15.5,
#        'min': 14.59999942779541},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 18.111906051635742,
#        'max': 18.111906051635742,
#        'min': 18.111906051635742},
#       {'depth': '0.4-1 m below ground',
#        'average': 5.903707504272461,
#        'max': 5.903707504272461,
#        'min': 5.903707504272461},
#       {'depth': '1-2 m below ground',
#        'average': 13.94312858581543,
#        'max': 13.94312858581543,
#        'min': 13.94312858581543}]}],
#    '_links': {'self': {'href': '/v2/weather/locations/40,-105/forecasts/2020-04-12'}}},
#   {'date': '2020-04-13',
#    'location': {'latitude': 40.0, 'longitude': -105.0},
#    'forecast': [{'startTime': '2020-04-13T00:00:00+00:00',
#      'endTime': '2020-04-13T23:59:59+00:00',
#      'conditionsCode': 'F31',
#      'conditionsText': 'Cloudy, Moderate Rain, Light Wind/Calm',
#      'temperatures': {'max': 0.4833333194255829,
#       'min': -8.350000381469727,
#       'units': 'C'},
#      'precipitation': {'chance': 100.0,
#       'amount': 6.125000104308128,
#       'units': 'mm'},
#      'sky': {'cloudCover': 100.0, 'sunshine': 0.0},
#      'solar': {'amount': 5784.0, 'units': 'Wh/m^2'},
#      'relativeHumidity': {'average': 82.25000031789143,
#       'max': 92.80000305175781,
#       'min': 59.900001525878906},
#      'wind': {'average': 3.0090024360908827,
#       'max': 5.791448761840663,
#       'min': 1.709980939237059,
#       'units': 'm/sec',
#       'bearing': 48.8,
#       'direction': 'NE'},
#      'dewPoint': {'amount': -6.395438673656958, 'units': 'C'},
#      'soilTemperatures': [{'depth': '0-0.1 m below ground',
#        'average': 3.1688008904457092,
#        'max': 7.906201362609863,
#        'min': 1.0499999523162842,
#        'units': 'C'},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 9.52985429763794,
#        'max': 10.023333549499512,
#        'min': 8.981797218322754,
#        'units': 'C'},
#       {'depth': '0.4-1 m below ground',
#        'average': 8.449098348617554,
#        'max': 8.472363471984863,
#        'min': 8.40235710144043,
#        'units': 'C'},
#       {'depth': '1-2 m below ground',
#        'average': 7.664674460887909,
#        'max': 7.671757698059082,
#        'min': 7.651757717132568,
#        'units': 'C'}],
#      'soilMoisture': [{'depth': '0-0.1 m below ground',
#        'average': 16.125,
#        'max': 18.19999885559082,
#        'min': 15.5},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 18.078572511672974,
#        'max': 18.111906051635742,
#        'min': 18.011905670166016},
#       {'depth': '0.4-1 m below ground',
#        'average': 5.903707504272461,
#        'max': 5.903707504272461,
#        'min': 5.903707504272461},
#       {'depth': '1-2 m below ground',
#        'average': 13.94312858581543,
#        'max': 13.94312858581543,
#        'min': 13.94312858581543}]}],
#    '_links': {'self': {'href': '/v2/weather/locations/40,-105/forecasts/2020-04-13'}}},
#   {'date': '2020-04-14',
#    'location': {'latitude': 40.0, 'longitude': -105.0},
#    'forecast': [{'startTime': '2020-04-14T00:00:00+00:00',
#      'endTime': '2020-04-14T23:59:59+00:00',
#      'conditionsCode': 'E21',
#      'conditionsText': 'Mostly Cloudy, Light Rain, Light Wind/Calm',
#      'temperatures': {'max': 6.027815818786621,
#       'min': -7.083255290985107,
#       'units': 'C'},
#      'precipitation': {'chance': 100.0,
#       'amount': 1.2499999981373549,
#       'units': 'mm'},
#      'sky': {'cloudCover': 80.25, 'sunshine': 19.75},
#      'solar': {'amount': 7146.0, 'units': 'Wh/m^2'},
#      'relativeHumidity': {'average': 70.60833326975505,
#       'max': 90.5999984741211,
#       'min': 33.70000076293945},
#      'wind': {'average': 1.4536550666622041,
#       'max': 4.538157542993436,
#       'min': 0.2207181000317976,
#       'units': 'm/sec',
#       'bearing': 12.0,
#       'direction': 'NNE'},
#      'dewPoint': {'amount': -7.3380807869226, 'units': 'C'},
#      'soilTemperatures': [{'depth': '0-0.1 m below ground',
#        'average': 0.8992268797010183,
#        'max': 4.335864067077637,
#        'min': -0.8499511480331421,
#        'units': 'C'},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 8.382194757461548,
#        'max': 8.935318946838379,
#        'min': 7.893535137176514,
#        'units': 'C'},
#       {'depth': '0.4-1 m below ground',
#        'average': 8.454860965410868,
#        'max': 8.472363471984863,
#        'min': 8.412363052368164,
#        'units': 'C'},
#       {'depth': '1-2 m below ground',
#        'average': 7.688256740570068,
#        'max': 7.701171875,
#        'min': 7.670000076293945,
#        'units': 'C'}],
#      'soilMoisture': [{'depth': '0-0.1 m below ground',
#        'average': 18.574999411900837,
#        'max': 19.399999618530273,
#        'min': 18.19999885559082},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 18.095239241917927,
#        'max': 18.111906051635742,
#        'min': 18.011905670166016},
#       {'depth': '0.4-1 m below ground',
#        'average': 5.903707504272461,
#        'max': 5.903707504272461,
#        'min': 5.903707504272461},
#       {'depth': '1-2 m below ground',
#        'average': 13.94312858581543,
#        'max': 13.94312858581543,
#        'min': 13.94312858581543}]}],
#    '_links': {'self': {'href': '/v2/weather/locations/40,-105/forecasts/2020-04-14'}}},
#   {'date': '2020-04-15',
#    'location': {'latitude': 40.0, 'longitude': -105.0},
#    'forecast': [{'startTime': '2020-04-15T00:00:00+00:00',
#      'endTime': '2020-04-15T23:59:59+00:00',
#      'conditionsCode': 'E21',
#      'conditionsText': 'Mostly Cloudy, Light Rain, Light Wind/Calm',
#      'temperatures': {'max': 9.165584564208984,
#       'min': -2.44921875,
#       'units': 'C'},
#      'precipitation': {'chance': 65.83333587646484,
#       'amount': 0.6250000186264515,
#       'units': 'mm'},
#      'sky': {'cloudCover': 85.375, 'sunshine': 14.625},
#      'solar': {'amount': 6252.0, 'units': 'Wh/m^2'},
#      'relativeHumidity': {'average': 48.02916622161865,
#       'max': 60.70000076293945,
#       'min': 33.0},
#      'wind': {'average': 2.286146816459482,
#       'max': 6.012114706288609,
#       'min': 0.7941544169541271,
#       'units': 'm/sec',
#       'bearing': 264.1,
#       'direction': 'W'},
#      'dewPoint': {'amount': -7.266825725215896, 'units': 'C'},
#      'soilTemperatures': [{'depth': '0-0.1 m below ground',
#        'average': 3.952690670887629,
#        'max': 8.168286323547363,
#        'min': 2.213549852371216,
#        'units': 'C'},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 7.582927246888478,
#        'max': 7.870397090911865,
#        'min': 7.408339977264404,
#        'units': 'C'},
#       {'depth': '0.4-1 m below ground',
#        'average': 8.360966761906942,
#        'max': 8.4121675491333,
#        'min': 8.292363166809082,
#        'units': 'C'},
#       {'depth': '1-2 m below ground',
#        'average': 7.707566678524017,
#        'max': 7.711757659912109,
#        'min': 7.701367378234863,
#        'units': 'C'}],
#      'soilMoisture': [{'depth': '0-0.1 m below ground',
#        'average': 19.40416630109151,
#        'max': 19.899999618530273,
#        'min': 19.200000762939453},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 18.111906051635742,
#        'max': 18.111906051635742,
#        'min': 18.111906051635742},
#       {'depth': '0.4-1 m below ground',
#        'average': 5.903707504272461,
#        'max': 5.903707504272461,
#        'min': 5.903707504272461},
#       {'depth': '1-2 m below ground',
#        'average': 13.94312858581543,
#        'max': 13.94312858581543,
#        'min': 13.94312858581543}]}],
#    '_links': {'self': {'href': '/v2/weather/locations/40,-105/forecasts/2020-04-15'}}},
#   {'date': '2020-04-16',
#    'location': {'latitude': 40.0, 'longitude': -105.0},
#    'forecast': [{'startTime': '2020-04-16T00:00:00+00:00',
#      'endTime': '2020-04-16T23:59:59+00:00',
#      'conditionsCode': 'E21',
#      'conditionsText': 'Mostly Cloudy, Light Rain, Light Wind/Calm',
#      'temperatures': {'max': 12.54019546508789,
#       'min': 0.87518310546875,
#       'units': 'C'},
#      'precipitation': {'chance': 88.33333587646484,
#       'amount': 1.6874999552965164,
#       'units': 'mm'},
#      'sky': {'cloudCover': 70.5, 'sunshine': 29.5},
#      'solar': {'amount': 6810.0, 'units': 'Wh/m^2'},
#      'relativeHumidity': {'average': 57.71250065167745,
#       'max': 90.0999984741211,
#       'min': 27.899999618530273},
#      'wind': {'average': 3.328499268563832,
#       'max': 4.7833676296584695,
#       'min': 2.182992676222989,
#       'units': 'm/sec',
#       'bearing': 175.8,
#       'direction': 'S'},
#      'dewPoint': {'amount': -3.499543652454541, 'units': 'C'},
#      'soilTemperatures': [{'depth': '0-0.1 m below ground',
#        'average': 6.669709205627441,
#        'max': 11.850000381469727,
#        'min': 3.6629881858825684,
#        'units': 'C'},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 7.37675541639328,
#        'max': 7.476250171661377,
#        'min': 7.246250152587891,
#        'units': 'C'},
#       {'depth': '0.4-1 m below ground',
#        'average': 8.238118569056192,
#        'max': 8.289030075073242,
#        'min': 8.182363510131836,
#        'units': 'C'},
#       {'depth': '1-2 m below ground',
#        'average': 7.721539715925853,
#        'max': 7.73117208480835,
#        'min': 7.711757659912109,
#        'units': 'C'}],
#      'soilMoisture': [{'depth': '0-0.1 m below ground',
#        'average': 20.412499984105427,
#        'max': 20.700000762939453,
#        'min': 19.899999618530273},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 18.078572511672974,
#        'max': 18.111906051635742,
#        'min': 18.011905670166016},
#       {'depth': '0.4-1 m below ground',
#        'average': 5.903707504272461,
#        'max': 5.903707504272461,
#        'min': 5.903707504272461},
#       {'depth': '1-2 m below ground',
#        'average': 13.94312858581543,
#        'max': 13.94312858581543,
#        'min': 13.94312858581543}]}],
#    '_links': {'self': {'href': '/v2/weather/locations/40,-105/forecasts/2020-04-16'}}},
#   {'date': '2020-04-17',
#    'location': {'latitude': 40.0, 'longitude': -105.0},
#    'forecast': [{'startTime': '2020-04-17T00:00:00+00:00',
#      'endTime': '2020-04-17T23:59:59+00:00',
#      'conditionsCode': 'F41',
#      'conditionsText': 'Cloudy, Heavy Rain, Light Wind/Calm',
#      'temperatures': {'max': 11.500755310058594,
#       'min': 0.43886393308639526,
#       'units': 'C'},
#      'precipitation': {'chance': 81.66666412353516,
#       'amount': 8.375000216066837,
#       'units': 'mm'},
#      'sky': {'cloudCover': 99.75, 'sunshine': 0.25},
#      'solar': {'amount': 3750.0, 'units': 'Wh/m^2'},
#      'relativeHumidity': {'average': 84.31250015894572,
#       'max': 97.5999984741211,
#       'min': 47.400001525878906},
#      'wind': {'average': 3.772518314023307,
#       'max': 8.791746546848088,
#       'min': 1.8413662773306223,
#       'units': 'm/sec',
#       'bearing': 0.9,
#       'direction': 'N'},
#      'dewPoint': {'amount': 1.0143831138092079, 'units': 'C'},
#      'soilTemperatures': [{'depth': '0-0.1 m below ground',
#        'average': 7.261854390303294,
#        'max': 11.411432266235352,
#        'min': 5.449975490570068,
#        'units': 'C'},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 7.576577961444855,
#        'max': 7.654160022735596,
#        'min': 7.492089748382568,
#        'units': 'C'},
#       {'depth': '0.4-1 m below ground',
#        'average': 8.15019694964091,
#        'max': 8.182363510131836,
#        'min': 8.1123628616333,
#        'units': 'C'},
#       {'depth': '1-2 m below ground',
#        'average': 7.728873749574025,
#        'max': 7.731777191162109,
#        'min': 7.721171855926514,
#        'units': 'C'}],
#      'soilMoisture': [{'depth': '0-0.1 m below ground',
#        'average': 22.487499872843426,
#        'max': 25.899999618530273,
#        'min': 19.899999618530273},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 18.05773909886678,
#        'max': 18.111906051635742,
#        'min': 18.011905670166016},
#       {'depth': '0.4-1 m below ground',
#        'average': 5.903707504272461,
#        'max': 5.903707504272461,
#        'min': 5.903707504272461},
#       {'depth': '1-2 m below ground',
#        'average': 13.94312858581543,
#        'max': 13.94312858581543,
#        'min': 13.94312858581543}]}],
#    '_links': {'self': {'href': '/v2/weather/locations/40,-105/forecasts/2020-04-17'}}},
#   {'date': '2020-04-18',
#    'location': {'latitude': 40.0, 'longitude': -105.0},
#    'forecast': [{'startTime': '2020-04-18T00:00:00+00:00',
#      'endTime': '2020-04-18T23:59:59+00:00',
#      'conditionsCode': 'D11',
#      'conditionsText': 'Partly Cloudy, No Rain, Light Wind/Calm',
#      'temperatures': {'max': 18.516666412353516,
#       'min': -0.06905598938465118,
#       'units': 'C'},
#      'precipitation': {'chance': 0.0, 'amount': 0.0, 'units': 'mm'},
#      'sky': {'cloudCover': 51.5, 'sunshine': 48.5},
#      'solar': {'amount': 6402.0, 'units': 'Wh/m^2'},
#      'relativeHumidity': {'average': 63.3791663646698,
#       'max': 89.30000305175781,
#       'min': 26.899999618530273},
#      'wind': {'average': 1.6164777814808398,
#       'max': 3.3350804739304794,
#       'min': 0.05270724142007445,
#       'units': 'm/sec',
#       'bearing': 165.6,
#       'direction': 'SSE'},
#      'dewPoint': {'amount': -1.0406030036226934, 'units': 'C'},
#      'soilTemperatures': [{'depth': '0-0.1 m below ground',
#        'average': 6.073760390281677,
#        'max': 11.57763671875,
#        'min': 4.25,
#        'units': 'C'},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 7.3422525723775225,
#        'max': 7.4887566566467285,
#        'min': 7.202089786529541,
#        'units': 'C'},
#       {'depth': '0.4-1 m below ground',
#        'average': 8.061366399129232,
#        'max': 8.1088285446167,
#        'min': 8.012246131896973,
#        'units': 'C'},
#       {'depth': '1-2 m below ground',
#        'average': 7.737610658009847,
#        'max': 7.741777420043945,
#        'min': 7.731777191162109,
#        'units': 'C'}],
#      'soilMoisture': [{'depth': '0-0.1 m below ground',
#        'average': 25.47499982515971,
#        'max': 25.833332061767578,
#        'min': 24.69999885559082},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 18.20773967107137,
#        'max': 18.21190643310547,
#        'min': 18.145238876342773},
#       {'depth': '0.4-1 m below ground',
#        'average': 5.903707504272461,
#        'max': 5.903707504272461,
#        'min': 5.903707504272461},
#       {'depth': '1-2 m below ground',
#        'average': 13.94312858581543,
#        'max': 13.94312858581543,
#        'min': 13.94312858581543}]}],
#    '_links': {'self': {'href': '/v2/weather/locations/40,-105/forecasts/2020-04-18'}}},
#   {'date': '2020-04-19',
#    'location': {'latitude': 40.0, 'longitude': -105.0},
#    'forecast': [{'startTime': '2020-04-19T00:00:00+00:00',
#      'endTime': '2020-04-19T23:59:59+00:00',
#      'conditionsCode': 'E51',
#      'conditionsText': 'Mostly Cloudy, Trace Amount of Rain, Light Wind/Calm',
#      'temperatures': {'max': 19.672990798950195,
#       'min': 5.50927734375,
#       'units': 'C'},
#      'precipitation': {'chance': 0.0,
#       'amount': 0.06250000186264515,
#       'units': 'mm'},
#      'sky': {'cloudCover': 69.5, 'sunshine': 30.5},
#      'solar': {'amount': 7470.0, 'units': 'Wh/m^2'},
#      'relativeHumidity': {'average': 44.33750025431315,
#       'max': 55.0,
#       'min': 22.600000381469727},
#      'wind': {'average': 2.7107785539386327,
#       'max': 8.388354985856033,
#       'min': 1.0932239353317579,
#       'units': 'm/sec',
#       'bearing': 269.5,
#       'direction': 'W'},
#      'dewPoint': {'amount': -0.22728889341635594, 'units': 'C'},
#      'soilTemperatures': [{'depth': '0-0.1 m below ground',
#        'average': 10.798388620217642,
#        'max': 16.797679901123047,
#        'min': 7.063574314117432,
#        'units': 'C'},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 7.7176367243131,
#        'max': 8.168339729309082,
#        'min': 7.447493553161621,
#        'units': 'C'},
#       {'depth': '0.4-1 m below ground',
#        'average': 7.998094181219737,
#        'max': 8.01236343383789,
#        'min': 7.991777420043945,
#        'units': 'C'},
#       {'depth': '1-2 m below ground',
#        'average': 7.748658875624339,
#        'max': 7.751777172088623,
#        'min': 7.741777420043945,
#        'units': 'C'}],
#      'soilMoisture': [{'depth': '0-0.1 m below ground',
#        'average': 24.045833031336468,
#        'max': 24.666667938232422,
#        'min': 22.700000762939453},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 18.28690528869629,
#        'max': 18.311904907226562,
#        'min': 18.21190643310547},
#       {'depth': '0.4-1 m below ground',
#        'average': 5.903707504272461,
#        'max': 5.903707504272461,
#        'min': 5.903707504272461},
#       {'depth': '1-2 m below ground',
#        'average': 13.94312858581543,
#        'max': 13.94312858581543,
#        'min': 13.94312858581543}]}],
#    '_links': {'self': {'href': '/v2/weather/locations/40,-105/forecasts/2020-04-19'}}},
#   {'date': '2020-04-20',
#    'location': {'latitude': 40.0, 'longitude': -105.0},
#    'forecast': [{'startTime': '2020-04-20T00:00:00+00:00',
#      'endTime': '2020-04-20T23:59:59+00:00',
#      'conditionsCode': 'E31',
#      'conditionsText': 'Mostly Cloudy, Moderate Rain, Light Wind/Calm',
#      'temperatures': {'max': 14.707759857177734,
#       'min': 6.455403804779053,
#       'units': 'C'},
#      'precipitation': {'chance': 55.0,
#       'amount': 4.374999957159162,
#       'units': 'mm'},
#      'sky': {'cloudCover': 81.0, 'sunshine': 19.0},
#      'solar': {'amount': 5742.0, 'units': 'Wh/m^2'},
#      'relativeHumidity': {'average': 74.037500222524,
#       'max': 91.9000015258789,
#       'min': 51.400001525878906},
#      'wind': {'average': 3.6715351982511444,
#       'max': 7.049499248061542,
#       'min': 0.8910234515280471,
#       'units': 'm/sec',
#       'bearing': 33.1,
#       'direction': 'NNE'},
#      'dewPoint': {'amount': 5.338807563061056, 'units': 'C'},
#      'soilTemperatures': [{'depth': '0-0.1 m below ground',
#        'average': 12.179790258407593,
#        'max': 16.146915435791016,
#        'min': 9.624486923217773,
#        'units': 'C'},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 8.570858597755432,
#        'max': 8.840429306030273,
#        'min': 8.231673240661621,
#        'units': 'C'},
#       {'depth': '0.4-1 m below ground',
#        'average': 8.026752094427744,
#        'max': 8.062226295471191,
#        'min': 7.995689868927002,
#        'units': 'C'},
#       {'depth': '1-2 m below ground',
#        'average': 7.758255223433177,
#        'max': 7.761171817779541,
#        'min': 7.751172065734863,
#        'units': 'C'}],
#      'soilMoisture': [{'depth': '0-0.1 m below ground',
#        'average': 23.454166094462078,
#        'max': 24.100000381469727,
#        'min': 22.766666412353516},
#       {'depth': '0.1-0.4 m below ground',
#        'average': 18.21190643310547,
#        'max': 18.21190643310547,
#        'min': 18.21190643310547},
#       {'depth': '0.4-1 m below ground',
#        'average': 5.912040829658508,
#        'max': 6.003707408905029,
#        'min': 5.903707504272461},
#       {'depth': '1-2 m below ground',
#        'average': 13.94312858581543,
#        'max': 13.94312858581543,
#        'min': 13.94312858581543}]}],
#    '_links': {'self': {'href': '/v2/weather/locations/40,-105/forecasts/2020-04-20'}}}],
#  '_links': {'self': {'href': '/v2/weather/locations/40,-105/forecasts/2020-04-11,2020-04-27?limit=10'},
#   'next': {'href': '/v2/weather/locations/40,-105/forecasts/2020-04-11,2020-04-27?limit=10&offset=10'}}}

# %% [markdown]
# ### Extract Main Forecast

# %%
# Define vaues for dropping and renaming columns
forecast_main_lon_lat_cols = ['longitude', 'latitude']

forecast_main_drop_cols = [
    'temperatures.units', 'precipitation.units',
    'solar.units', 'wind.units', 'dewPoint.units'
]

forecast_main_mapping = {
    'startTime': 'start_time',
    'endTime': 'end_time',
    'conditionsCode': 'conditions_code',
    'conditionsText': 'conditions_text',
    'temperatures.max': 'temp_max_cels',
    'temperatures.min': 'temp_min_cels',
    'precipitation.chance': 'precip_chance_%',
    'precipitation.amount': 'precip_amount_mm',
    'sky.cloudCover': 'sky_cloud_cover_%',
    'sky.sunshine': 'sky_sunshine_%',
    'solar.amount': 'solar_energy_w_h_per_m2',
    'relativeHumidity.average': 'rel_humidity_avg_%',
    'relativeHumidity.max': 'rel_humidity_max_%',
    'relativeHumidity.min': 'rel_humidity_min_%',
    'wind.average': 'wind_avg_m_per_sec',
    'wind.max': 'wind_max_m_per_sec',
    'wind.min': 'wind_min_m_per_sec',
    'wind.bearing': 'wind_bearing_deg',
    'wind.direction': 'wind_direction_compass',
    'dewPoint.amount': 'dew_point_cels'
}

# %%
# Extract data from forecast to dataframe
rmnp_forecast_main_df = extract_data_geolocation.extract_forecast_main_data(
    rmnp_forecast)

# %%
# Display dataframe
rmnp_forecast_main_df

# %%
# Clean dataframe and covert to geodataframe
rmnp_forecast_main_gdf = clean_data_geolocation.clean_dataframe(
    rmnp_forecast_main_df, forecast_main_lon_lat_cols, 
    forecast_main_drop_cols, forecast_main_mapping)

# %%
# Display cleaned data
rmnp_forecast_main_gdf

# %% [markdown]
# ### Extract Soil Forecast

# %%
# Define vaues for dropping and renaming columns
forecast_soil_lon_lat_cols = ['longitude', 'latitude']

forecast_soil_drop_cols = ['units']

forecast_soil_mapping = {
    'average_temp': 'soil_temp_avg_cels',
    'max_temp': 'soil_temp_max_cels',
    'min_temp': 'soil_temp_min_cels',
    'average_moisture': 'soil_moisture_avg_%',
    'max_moisture': 'soil_moisture_max_%',
    'min_moisture': 'soil_moisture_min_%',
}

# %%
# Extract data from forecast to dataframe
rmnp_forecast_soil_df = extract_data_geolocation.extract_forecast_soil(
    rmnp_forecast)

# %%
# Display dataframe (MultiIndexed)
rmnp_forecast_soil_df
# Out:
#                            average_temp   max_temp   min_temp units  \
# date       ground_depth_m
# 2020-04-11 0-0.1              13.616608  18.091724  10.198389     C
#            0.1-0.4            10.167496  10.330000  10.090000     C
#            0.4-1               8.070495   8.172949   7.972969     C
#            1-2                 7.614110   7.621758   7.601758     C
# 2020-04-12 0-0.1              11.364468  17.637533   7.704883     C
#            0.1-0.4            10.356250  10.530000  10.060000     C
#            0.4-1               8.301961   8.392364   8.186081     C
#            1-2                 7.640649   7.651758   7.623314     C
# 2020-04-13 0-0.1               3.168801   7.906201   1.050000     C
#            0.1-0.4             9.529854  10.023334   8.981797     C
#            0.4-1               8.449098   8.472363   8.402357     C
#            1-2                 7.664674   7.671758   7.651758     C
# 2020-04-14 0-0.1               0.899227   4.335864  -0.849951     C
#            0.1-0.4             8.382195   8.935319   7.893535     C
#            0.4-1               8.454861   8.472363   8.412363     C
#            1-2                 7.688257   7.701172   7.670000     C
# 2020-04-15 0-0.1               3.952691   8.168286   2.213550     C
#            0.1-0.4             7.582927   7.870397   7.408340     C
#            0.4-1               8.360967   8.412168   8.292363     C
#            1-2                 7.707567   7.711758   7.701367     C
# 2020-04-16 0-0.1               6.669709  11.850000   3.662988     C
#            0.1-0.4             7.376755   7.476250   7.246250     C
#            0.4-1               8.238119   8.289030   8.182364     C
#            1-2                 7.721540   7.731172   7.711758     C
# 2020-04-17 0-0.1               7.261854  11.411432   5.449975     C
#            0.1-0.4             7.576578   7.654160   7.492090     C
#            0.4-1               8.150197   8.182364   8.112363     C
#            1-2                 7.728874   7.731777   7.721172     C
# 2020-04-18 0-0.1               6.073760  11.577637   4.250000     C
#            0.1-0.4             7.342253   7.488757   7.202090     C
#            0.4-1               8.061366   8.108829   8.012246     C
#            1-2                 7.737611   7.741777   7.731777     C
# 2020-04-19 0-0.1              10.798389  16.797680   7.063574     C
#            0.1-0.4             7.717637   8.168340   7.447494     C
#            0.4-1               7.998094   8.012363   7.991777     C
#            1-2                 7.748659   7.751777   7.741777     C
# 2020-04-20 0-0.1              12.179790  16.146915   9.624487     C
#            0.1-0.4             8.570859   8.840429   8.231673     C
#            0.4-1               8.026752   8.062226   7.995690     C
#            1-2                 7.758255   7.761172   7.751172     C
#
#                            average_moisture  max_moisture  min_moisture  \
# date       ground_depth_m
# 2020-04-11 0-0.1                  15.100000     15.299999     14.700000
#            0.1-0.4                18.349405     18.411905     18.111906
#            0.4-1                   5.903708      5.903708      5.903708
#            1-2                    13.943129     13.943129     13.943129
# 2020-04-12 0-0.1                  15.091666     15.500000     14.599999
#            0.1-0.4                18.111906     18.111906     18.111906
#            0.4-1                   5.903708      5.903708      5.903708
#            1-2                    13.943129     13.943129     13.943129
# 2020-04-13 0-0.1                  16.125000     18.199999     15.500000
#            0.1-0.4                18.078573     18.111906     18.011906
#            0.4-1                   5.903708      5.903708      5.903708
#            1-2                    13.943129     13.943129     13.943129
# 2020-04-14 0-0.1                  18.574999     19.400000     18.199999
#            0.1-0.4                18.095239     18.111906     18.011906
#            0.4-1                   5.903708      5.903708      5.903708
#            1-2                    13.943129     13.943129     13.943129
# 2020-04-15 0-0.1                  19.404166     19.900000     19.200001
#            0.1-0.4                18.111906     18.111906     18.111906
#            0.4-1                   5.903708      5.903708      5.903708
#            1-2                    13.943129     13.943129     13.943129
# 2020-04-16 0-0.1                  20.412500     20.700001     19.900000
#            0.1-0.4                18.078573     18.111906     18.011906
#            0.4-1                   5.903708      5.903708      5.903708
#            1-2                    13.943129     13.943129     13.943129
# 2020-04-17 0-0.1                  22.487500     25.900000     19.900000
#            0.1-0.4                18.057739     18.111906     18.011906
#            0.4-1                   5.903708      5.903708      5.903708
#            1-2                    13.943129     13.943129     13.943129
# 2020-04-18 0-0.1                  25.475000     25.833332     24.699999
#            0.1-0.4                18.207740     18.211906     18.145239
#            0.4-1                   5.903708      5.903708      5.903708
#            1-2                    13.943129     13.943129     13.943129
# 2020-04-19 0-0.1                  24.045833     24.666668     22.700001
#            0.1-0.4                18.286905     18.311905     18.211906
#            0.4-1                   5.903708      5.903708      5.903708
#            1-2                    13.943129     13.943129     13.943129
# 2020-04-20 0-0.1                  23.454166     24.100000     22.766666
#            0.1-0.4                18.211906     18.211906     18.211906
#            0.4-1                   5.912041      6.003707      5.903708
#            1-2                    13.943129     13.943129     13.943129
#
#                            latitude  longitude
# date       ground_depth_m
# 2020-04-11 0-0.1               40.0     -105.0
#            0.1-0.4             40.0     -105.0
#            0.4-1               40.0     -105.0
#            1-2                 40.0     -105.0
# 2020-04-12 0-0.1               40.0     -105.0
#            0.1-0.4             40.0     -105.0
#            0.4-1               40.0     -105.0
#            1-2                 40.0     -105.0
# 2020-04-13 0-0.1               40.0     -105.0
#            0.1-0.4             40.0     -105.0
#            0.4-1               40.0     -105.0
#            1-2                 40.0     -105.0
# 2020-04-14 0-0.1               40.0     -105.0
#            0.1-0.4             40.0     -105.0
#            0.4-1               40.0     -105.0
#            1-2                 40.0     -105.0
# 2020-04-15 0-0.1               40.0     -105.0
#            0.1-0.4             40.0     -105.0
#            0.4-1               40.0     -105.0
#            1-2                 40.0     -105.0
# 2020-04-16 0-0.1               40.0     -105.0
#            0.1-0.4             40.0     -105.0
#            0.4-1               40.0     -105.0
#            1-2                 40.0     -105.0
# 2020-04-17 0-0.1               40.0     -105.0
#            0.1-0.4             40.0     -105.0
#            0.4-1               40.0     -105.0
#            1-2                 40.0     -105.0
# 2020-04-18 0-0.1               40.0     -105.0
#            0.1-0.4             40.0     -105.0
#            0.4-1               40.0     -105.0
#            1-2                 40.0     -105.0
# 2020-04-19 0-0.1               40.0     -105.0
#            0.1-0.4             40.0     -105.0
#            0.4-1               40.0     -105.0
#            1-2                 40.0     -105.0
# 2020-04-20 0-0.1               40.0     -105.0
#            0.1-0.4             40.0     -105.0
#            0.4-1               40.0     -105.0
#            1-2                 40.0     -105.0

# %%
# Clean dataframe and covert to geodataframe
rmnp_forecast_soil_gdf = clean_data_geolocation.clean_dataframe(
    rmnp_forecast_soil_df, forecast_soil_lon_lat_cols,
    forecast_soil_drop_cols, forecast_soil_mapping)

# %%
# Display cleaned data (MultiIndexed)
rmnp_forecast_soil_gdf
# Out:
#                            soil_temp_avg_cels  soil_temp_max_cels  \
# date       ground_depth_m
# 2020-04-11 0-0.1                    13.616608           18.091724
#            0.1-0.4                  10.167496           10.330000
#            0.4-1                     8.070495            8.172949
#            1-2                       7.614110            7.621758
# 2020-04-12 0-0.1                    11.364468           17.637533
#            0.1-0.4                  10.356250           10.530000
#            0.4-1                     8.301961            8.392364
#            1-2                       7.640649            7.651758
# 2020-04-13 0-0.1                     3.168801            7.906201
#            0.1-0.4                   9.529854           10.023334
#            0.4-1                     8.449098            8.472363
#            1-2                       7.664674            7.671758
# 2020-04-14 0-0.1                     0.899227            4.335864
#            0.1-0.4                   8.382195            8.935319
#            0.4-1                     8.454861            8.472363
#            1-2                       7.688257            7.701172
# 2020-04-15 0-0.1                     3.952691            8.168286
#            0.1-0.4                   7.582927            7.870397
#            0.4-1                     8.360967            8.412168
#            1-2                       7.707567            7.711758
# 2020-04-16 0-0.1                     6.669709           11.850000
#            0.1-0.4                   7.376755            7.476250
#            0.4-1                     8.238119            8.289030
#            1-2                       7.721540            7.731172
# 2020-04-17 0-0.1                     7.261854           11.411432
#            0.1-0.4                   7.576578            7.654160
#            0.4-1                     8.150197            8.182364
#            1-2                       7.728874            7.731777
# 2020-04-18 0-0.1                     6.073760           11.577637
#            0.1-0.4                   7.342253            7.488757
#            0.4-1                     8.061366            8.108829
#            1-2                       7.737611            7.741777
# 2020-04-19 0-0.1                    10.798389           16.797680
#            0.1-0.4                   7.717637            8.168340
#            0.4-1                     7.998094            8.012363
#            1-2                       7.748659            7.751777
# 2020-04-20 0-0.1                    12.179790           16.146915
#            0.1-0.4                   8.570859            8.840429
#            0.4-1                     8.026752            8.062226
#            1-2                       7.758255            7.761172
#
#                            soil_temp_min_cels  soil_moisture_avg_%  \
# date       ground_depth_m
# 2020-04-11 0-0.1                    10.198389            15.100000
#            0.1-0.4                  10.090000            18.349405
#            0.4-1                     7.972969             5.903708
#            1-2                       7.601758            13.943129
# 2020-04-12 0-0.1                     7.704883            15.091666
#            0.1-0.4                  10.060000            18.111906
#            0.4-1                     8.186081             5.903708
#            1-2                       7.623314            13.943129
# 2020-04-13 0-0.1                     1.050000            16.125000
#            0.1-0.4                   8.981797            18.078573
#            0.4-1                     8.402357             5.903708
#            1-2                       7.651758            13.943129
# 2020-04-14 0-0.1                    -0.849951            18.574999
#            0.1-0.4                   7.893535            18.095239
#            0.4-1                     8.412363             5.903708
#            1-2                       7.670000            13.943129
# 2020-04-15 0-0.1                     2.213550            19.404166
#            0.1-0.4                   7.408340            18.111906
#            0.4-1                     8.292363             5.903708
#            1-2                       7.701367            13.943129
# 2020-04-16 0-0.1                     3.662988            20.412500
#            0.1-0.4                   7.246250            18.078573
#            0.4-1                     8.182364             5.903708
#            1-2                       7.711758            13.943129
# 2020-04-17 0-0.1                     5.449975            22.487500
#            0.1-0.4                   7.492090            18.057739
#            0.4-1                     8.112363             5.903708
#            1-2                       7.721172            13.943129
# 2020-04-18 0-0.1                     4.250000            25.475000
#            0.1-0.4                   7.202090            18.207740
#            0.4-1                     8.012246             5.903708
#            1-2                       7.731777            13.943129
# 2020-04-19 0-0.1                     7.063574            24.045833
#            0.1-0.4                   7.447494            18.286905
#            0.4-1                     7.991777             5.903708
#            1-2                       7.741777            13.943129
# 2020-04-20 0-0.1                     9.624487            23.454166
#            0.1-0.4                   8.231673            18.211906
#            0.4-1                     7.995690             5.912041
#            1-2                       7.751172            13.943129
#
#                            soil_moisture_max_%  soil_moisture_min_%  \
# date       ground_depth_m
# 2020-04-11 0-0.1                     15.299999            14.700000
#            0.1-0.4                   18.411905            18.111906
#            0.4-1                      5.903708             5.903708
#            1-2                       13.943129            13.943129
# 2020-04-12 0-0.1                     15.500000            14.599999
#            0.1-0.4                   18.111906            18.111906
#            0.4-1                      5.903708             5.903708
#            1-2                       13.943129            13.943129
# 2020-04-13 0-0.1                     18.199999            15.500000
#            0.1-0.4                   18.111906            18.011906
#            0.4-1                      5.903708             5.903708
#            1-2                       13.943129            13.943129
# 2020-04-14 0-0.1                     19.400000            18.199999
#            0.1-0.4                   18.111906            18.011906
#            0.4-1                      5.903708             5.903708
#            1-2                       13.943129            13.943129
# 2020-04-15 0-0.1                     19.900000            19.200001
#            0.1-0.4                   18.111906            18.111906
#            0.4-1                      5.903708             5.903708
#            1-2                       13.943129            13.943129
# 2020-04-16 0-0.1                     20.700001            19.900000
#            0.1-0.4                   18.111906            18.011906
#            0.4-1                      5.903708             5.903708
#            1-2                       13.943129            13.943129
# 2020-04-17 0-0.1                     25.900000            19.900000
#            0.1-0.4                   18.111906            18.011906
#            0.4-1                      5.903708             5.903708
#            1-2                       13.943129            13.943129
# 2020-04-18 0-0.1                     25.833332            24.699999
#            0.1-0.4                   18.211906            18.145239
#            0.4-1                      5.903708             5.903708
#            1-2                       13.943129            13.943129
# 2020-04-19 0-0.1                     24.666668            22.700001
#            0.1-0.4                   18.311905            18.211906
#            0.4-1                      5.903708             5.903708
#            1-2                       13.943129            13.943129
# 2020-04-20 0-0.1                     24.100000            22.766666
#            0.1-0.4                   18.211906            18.211906
#            0.4-1                      6.003707             5.903708
#            1-2                       13.943129            13.943129
#
#                                               geometry
# date       ground_depth_m
# 2020-04-11 0-0.1           POINT (-105.00000 40.00000)
#            0.1-0.4         POINT (-105.00000 40.00000)
#            0.4-1           POINT (-105.00000 40.00000)
#            1-2             POINT (-105.00000 40.00000)
# 2020-04-12 0-0.1           POINT (-105.00000 40.00000)
#            0.1-0.4         POINT (-105.00000 40.00000)
#            0.4-1           POINT (-105.00000 40.00000)
#            1-2             POINT (-105.00000 40.00000)
# 2020-04-13 0-0.1           POINT (-105.00000 40.00000)
#            0.1-0.4         POINT (-105.00000 40.00000)
#            0.4-1           POINT (-105.00000 40.00000)
#            1-2             POINT (-105.00000 40.00000)
# 2020-04-14 0-0.1           POINT (-105.00000 40.00000)
#            0.1-0.4         POINT (-105.00000 40.00000)
#            0.4-1           POINT (-105.00000 40.00000)
#            1-2             POINT (-105.00000 40.00000)
# 2020-04-15 0-0.1           POINT (-105.00000 40.00000)
#            0.1-0.4         POINT (-105.00000 40.00000)
#            0.4-1           POINT (-105.00000 40.00000)
#            1-2             POINT (-105.00000 40.00000)
# 2020-04-16 0-0.1           POINT (-105.00000 40.00000)
#            0.1-0.4         POINT (-105.00000 40.00000)
#            0.4-1           POINT (-105.00000 40.00000)
#            1-2             POINT (-105.00000 40.00000)
# 2020-04-17 0-0.1           POINT (-105.00000 40.00000)
#            0.1-0.4         POINT (-105.00000 40.00000)
#            0.4-1           POINT (-105.00000 40.00000)
#            1-2             POINT (-105.00000 40.00000)
# 2020-04-18 0-0.1           POINT (-105.00000 40.00000)
#            0.1-0.4         POINT (-105.00000 40.00000)
#            0.4-1           POINT (-105.00000 40.00000)
#            1-2             POINT (-105.00000 40.00000)
# 2020-04-19 0-0.1           POINT (-105.00000 40.00000)
#            0.1-0.4         POINT (-105.00000 40.00000)
#            0.4-1           POINT (-105.00000 40.00000)
#            1-2             POINT (-105.00000 40.00000)
# 2020-04-20 0-0.1           POINT (-105.00000 40.00000)
#            0.1-0.4         POINT (-105.00000 40.00000)
#            0.4-1           POINT (-105.00000 40.00000)
#            1-2             POINT (-105.00000 40.00000)

# %% [markdown]
# ## Observed Weather

# %%
# Define vaues for dropping and renaming columns
observed_lon_lat_cols = ['location.longitude', 'location.latitude']

observed_drop_cols = [
    'temperatures.units', 'precipitation.units',
    'solar.units', 'wind.units'
]

observed_mapping = {
    'temperatures.max': 'temp_max_cels',
    'temperatures.min': 'temp_min_cels',
    'precipitation.amount': 'precip_amount_mm',
    'solar.amount': 'solar_energy_w_h_per_m2',
    'relativeHumidity.average': 'rel_humidity_avg_%',
    'relativeHumidity.max': 'rel_humidity_max_%',
    'relativeHumidity.min': 'rel_humidity_min_%',
    'wind.morningMax': 'wind_morning_max_m_per_sec',
    'wind.dayMax': 'wind_day_max_m_per_sec',
    'wind.average': 'wind_avg_m_per_sec',
}

# %%
# Get observed weather in raw form
rmnp_observed = aWhere.get_weather_observed(
    rmnp_latitude, rmnp_longitude)

# %%
# Display raw data return
rmnp_observed

# %%
# Extract data from forecast to dataframe
rmnp_observed_df = extract_data_geolocation.extract_observed_weather(
    rmnp_observed)

# %%
# Display dataframe
rmnp_observed_df

# %%
# Clean dataframe and covert to geodataframe
rmnp_observed_gdf = clean_data_geolocation.clean_dataframe(
    rmnp_observed_df, observed_lon_lat_cols,
    observed_drop_cols, observed_mapping)

# %%
# Display cleaned data
rmnp_observed_gdf

# %% [markdown]
# # Historic Norms

# %%
# Define vaues for dropping and renaming columns
norms_lon_lat_cols = ['location.longitude', 'location.latitude']

norms_drop_cols = [
    'meanTemp.units', 'maxTemp.units',
    'minTemp.units', 'precipitation.units', 'solar.units',
    'dailyMaxWind.units', 'averageWind.units'
]

norms_mapping = {
    'meanTemp.average': 'mean_temp_avg_cels',
    'meanTemp.stdDev': 'mean_temp_std_dev_cels',
    'maxTemp.average': 'max_temp_avg_cels',
    'maxTemp.stdDev': 'max_temp_std_dev_cels',
    'minTemp.average': 'min_temp_avg_cels',
    'minTemp.stdDev': 'min_temp_std_dev_cels',
    'precipitation.average': 'precip_avg_mm',
    'precipitation.stdDev': 'precip_std_dev_mm',
    'solar.average': 'solar_avg_w_h_per_m2',
    'minHumidity.average': 'min_humiduty_avg_%',
    'minHumidity.stdDev': 'min_humidity_std_dev_%',
    'maxHumidity.average': 'max_humiduty_avg_%',
    'maxHumidity.stdDev': 'max_humidity_std_dev_%',
    'dailyMaxWind.average': 'daily_max_wind_avg_m_per_sec',
    'dailyMaxWind.stdDev': 'daily_max_wind_std_dev_m_per_sec',
    'averageWind.average': 'average_wind_m_per_sec',
    'averageWind.stdDev': 'average_wind_std_dev_m_per_sec'
}

# %%
# Get norms in raw form
rmnp_norms = aWhere.get_weather_norms(
    rmnp_latitude, rmnp_longitude, 
    start_day='04-01', end_day='04-10')

# %%
# Display raw data return
rmnp_norms

# %%
# Extract data from forecast to dataframe
rmnp_norms_df = extract_data_geolocation.extract_historic_norms(
    rmnp_norms)

# %%
# Display dataframe
rmnp_norms_df

# %%
# Clean dataframe and covert to geodataframe
rmnp_norms_gdf = clean_data_geolocation.clean_dataframe(
    rmnp_norms_df, norms_lon_lat_cols,
    norms_drop_cols, norms_mapping)

# %%
# Display cleaned data
rmnp_norms_gdf
